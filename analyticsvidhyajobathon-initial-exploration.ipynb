# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from matplotlib import pyplot as plt
from sklearn import preprocessing 
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
input_df = pd.read_csv("/kaggle/input/jobathon-analytics-vidhya-health-insurance/Train.csv")

# %%
input_df.head()

# %%
input_df.describe()

# %%
input_df.isnull().values.any()

# %%
input_df.duplicated().sum()

# %%
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
input_df.hist(ax=ax)

# %%
input_df['City_Code'].value_counts()

# %%
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder() 
  
# Encode labels in column 'species'. 
input_df['City_Code']= label_encoder.fit_transform(input_df['City_Code']) 
  
input_df['City_Code'].unique()

# %%
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
input_df.hist(ax=ax)

# %%
input_df['Accomodation_Type'] =input_df['Accomodation_Type'].astype('category').cat.codes
input_df['Reco_Insurance_Type'] =input_df['Reco_Insurance_Type'].astype('category').cat.codes
input_df['Health Indicator'] =input_df['Health Indicator'].astype('category').cat.codes

# %%
input_df.head()

# %%
input_df.isna().any()

# %%
input_df['Holding_Policy_Duration'].isna().sum()
input_df['Holding_Policy_Type'].isna().sum()

# %%
input_df.corr(method='spearman')['Response']

# %% [markdown]
# ID                     0.007355
# City_Code             -0.002736
# Region_Code           -0.000932
# Accomodation_Type     -0.003143
# Reco_Insurance_Type    0.008909
# Upper_Age             -0.002818
# Lower_Age             -0.009249
# Health Indicator      -0.000160
# Holding_Policy_Type    0.009396
# Reco_Policy_Cat        0.094781
# Reco_Policy_Premium    0.004619
# Response               1.000000
# Name: Response, dtype: float64

# %%
input_df['Holding_Policy_Type']=input_df['Holding_Policy_Type'].fillna(input_df['Holding_Policy_Type'].mean())

# %%
input_df['Holding_Policy_Duration'].dtypes

# %%
input_df['Holding_Policy_Duration'].unique()

# %%
input_df['Holding_Policy_Duration'].replace({"14+": "15.0"}, inplace=True)

# %%
input_df['Holding_Policy_Duration']=input_df['Holding_Policy_Duration'].astype(float)

# %%
input_df['Holding_Policy_Duration']=input_df['Holding_Policy_Duration'].fillna(input_df['Holding_Policy_Duration'].mean())
